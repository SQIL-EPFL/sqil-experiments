# %%
import sqil_core as sqil
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib qt

# %% [markdown]
# ### Readout resonator spectroscopy

# %%
from sqil_experiments.measurements.rr_spec import rr_spec_analysis

path = r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-02\00064-cw_resonator_spectroscopy_vs_current_2025-10-02T093557"

datadict = sqil.extract_h5_data(path, get_metadata=True)
qpu = sqil.read_qpu(path, "qpu_old.json")

rr_spec_analysis(datadict=datadict, qpu=qpu)
plt.show()

# %% [markdown]
# ### Qubit spectroscopy

# %%
from sqil_experiments.measurements.qu_spec import qu_spec_analysis

path = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-06\04208-qubit_spectroscopy_hdawg_2025-12-06T040121"

datadict = sqil.extract_h5_data(path, get_metadata=True)
qpu = sqil.read_qpu(path, "qpu_old.json")

qu_spec_analysis(datadict=datadict, qpu=qpu)
plt.show()

# %% [markdown]
# ### T1

# %%
from sqil_experiments.measurements.T1 import analyze_T1

path = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-12\05329-T1_hdawg_2025-12-12T062000"

datadict = sqil.extract_h5_data(path, get_metadata=True)
qpu = sqil.read_qpu(path, "qpu_old.json")

analyze_T1(datadict=datadict, qpu=qpu)
plt.show()

# %% [markdown]
# ### T2 echo

# %%
from sqil_experiments.measurements.T2_echo import analyze_T2_echo

path = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-03\01257-T2_echo_hdawg_vs_index_2025-12-03T034603"

datadict = sqil.extract_h5_data(path, get_metadata=True)
qpu = sqil.read_qpu(path, "qpu_old.json")

analyze_T2_echo(datadict=datadict, qpu=qpu)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       3 path = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-03\01257-T2_echo_hdawg_vs_index_2025-12-03T034603"
#       5 datadict = sqil.extract_h5_data(path, get_metadata=True)
# ----> 6 qpu = sqil.read_qpu(path, "qpu_old.json")
#       8 analyze_T2_echo(datadict=datadict, qpu=qpu)
#       9 plt.show()
#
# File c:\Users\sqil\AppData\Local\pypoetry\Cache\virtualenvs\sqil-experiments-gl8RHkKX-py3.12\Lib\site-packages\sqil_core\utils\_read.py:214, in read_qpu(dir_path, filename)
#     212 def read_qpu(dir_path: str, filename: str) -> QPU:
#     213     """Reads QPU file stored in dir_path/filename using laboneq serializers."""
# --> 214     qpu = serializers.load(os.path.join(dir_path, filename))
#     215     return qpu
#
# ...

# %% [markdown]
# # CW

# %% [markdown]
# ### Stiching

# %%
# Rough transmon scan
path0 =  r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00131-cw_qubit_spectroscopy_vs_current_2025-10-03T000923"

paths = [
    # |10>
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00018-cw_qubit_spectroscopy_vs_current_2025-10-06T015830",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00258-cw_qubit_spectroscopy_vs_current_2025-10-04T165527",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00269-cw_qubit_spectroscopy_vs_current_2025-10-04T181446",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00279-cw_qubit_spectroscopy_vs_current_2025-10-04T203617",
    # |11>
    # r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00147-cw_qubit_spectroscopy_vs_current_2025-10-03T112955",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00019-cw_qubit_spectroscopy_vs_current_2025-10-06T033418",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00024-cw_qubit_spectroscopy_vs_current_2025-10-06T053057",
    # Anti-crossing
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00153-cw_qubit_spectroscopy_vs_current_2025-10-03T132052",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00193-cw_qubit_spectroscopy_vs_current_2025-10-04T020223",
    # Following |01> left
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00155-cw_qubit_spectroscopy_vs_current_2025-10-03T135806",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00156-cw_qubit_spectroscopy_vs_current_2025-10-03T141955",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00157-cw_qubit_spectroscopy_vs_current_2025-10-03T143339",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00158-cw_qubit_spectroscopy_vs_current_2025-10-03T144552",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00159-cw_qubit_spectroscopy_vs_current_2025-10-03T145823",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00162-cw_qubit_spectroscopy_vs_current_2025-10-03T153920",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00197-cw_qubit_spectroscopy_vs_current_2025-10-04T032851",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00201-cw_qubit_spectroscopy_vs_current_2025-10-04T042626",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00020-cw_qubit_spectroscopy_vs_current_2025-10-06T044529",
    # Following |01> right
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00225-cw_qubit_spectroscopy_vs_current_2025-10-04T111423",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00021-cw_qubit_spectroscopy_vs_current_2025-10-06T045542",
    # IDK
    # r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00240-cw_qubit_spectroscopy_vs_current_2025-10-04T122815",
    # r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00246-cw_qubit_spectroscopy_vs_current_2025-10-04T125214"
    # |20>
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00255-cw_qubit_spectroscopy_vs_current_2025-10-04T142932",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00023-cw_qubit_spectroscopy_vs_current_2025-10-06T051615",
]

datadict = sqil.extract_h5_data(path0, get_metadata=True)
qpu = sqil.read_qpu(path0, "qpu_old.json")
qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
fig, axs = sqil.plot_mag_phase(datadict=datadict["q0"], transpose=True)

for path in paths:
    datadict = sqil.extract_h5_data(path, get_metadata=True)
    qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
    sqil.plot_mag_phase(datadict=datadict["q0"], transpose=True, plot=(fig, axs))

fig.show()

# %% [markdown]
# ### Fit

# %%
from qutip import *


def get_transmon_AH(N, EC, EJ, EL=0, diagonalize=True):
    # Operators
    a = destroy(N)
    adag = a.dag()
    n = adag * a

    # Approximate qubit frequency and anharmonicity
    wq = np.sqrt(8 * EJ * EC) - EC
    alpha = EC

    # Zero-point fluctuations amplitude
    n_zpf = (EJ / (32 * EC)) ** 0.25
    phi_zpf = (2 * EC / EJ) ** 0.25
    # Charge operator
    n_op = 1j * n_zpf * (adag - a)
    # Phase operator
    phi_op = phi_zpf * (a + adag)

    # Hamiltonian
    H = wq * n - 0.5 * alpha * adag * adag * a * a + 0.5 * EL * phi_op**2

    if diagonalize:
        vals, vecs = H.eigenstates()
        U = Qobj(np.column_stack([ket.full() for ket in vecs]), dims=[N, N])
        H_diag = U.dag() * H * U
        n_diag = U.dag() * n_op * U
        phi_diag = U.dag() * phi_op * U
        return H_diag, n_diag, phi_diag

    return H, n_op, phi_op


def get_fluxonium(N, E_C, E_J, E_L, phi_ext=0.5, diagonalize=True):
    # Operators in the phase basis (harmonic oscillator)
    a = destroy(N)
    phi_zpf = (8 * E_C / E_L) ** 0.25  # Zero-point phase fluctuation
    n_zpf = (E_L / (8 * E_C)) ** 0.25  # Zero-point charge fluctuation

    phi_op = (a + a.dag()) * (phi_zpf / np.sqrt(2))
    n_op = 1j * (a.dag() - a) * (n_zpf / np.sqrt(2))

    H_charge = 4 * E_C * n_op**2
    H_induct = 0.5 * E_L * phi_op**2
    H_josephson = (
        -E_J * (phi_op - 2 * np.pi * phi_ext).cosm()
    )  # cosine term - expand exponential
    H = H_charge + H_induct + H_josephson

    if diagonalize:
        vals, vecs = H.eigenstates()
        U = Qobj(np.column_stack([ket.full() for ket in vecs]), dims=[N, N])
        H_diag = U.dag() * H * U
        n_diag = U.dag() * n_op * U
        phi_diag = U.dag() * phi_op * U
        return H_diag, n_diag, phi_diag
    return H, n_op, phi_op


# Transmon parameters
# EC_s = 2 * np.pi * 0.2612
# EJ_t = 2 * np.pi * 14.955
# # Fluxonium parameters
# EC_f = 2 * np.pi * 2
# EJ_f = 2 * np.pi * 14
# # Coupling
# EL = 2 * np.pi * 0.613

# Correct scaling
# # Transmon parameters
# EC_s = 2 * np.pi * 0.2612
# EJ_t = 2 * np.pi * 14.8
# # Fluxonium parameters
# EC_f = 2 * np.pi * 2
# EJ_f = 2 * np.pi * 17
# # Coupling
# EL = 2 * np.pi * 0.799

# Fixed junctions
# Transmon parameters
EC_s = 2 * np.pi * 0.2632
EJ_t = 2 * np.pi * 14.665
# Fluxonium parameters
EC_f = 2 * np.pi * 3
EJ_f = 2 * np.pi * 20
# Coupling
EL = 2 * np.pi * 0.795

# Simulated hilbert space dimension
N_t, N_f = 15, 35
I_t, I_f = qeye(N_t), qeye(N_f)
# Truncated dimension of diagonalized total H
N_trunc = 12
N_show = 7

phi_ext_sweep = np.concatenate(
    [[0, 0.1, 0.2], np.linspace(0.3, 0.7, 11), [0.8, 0.9, 1]]
)

# Anti-crossing
# phi_ext_sweep = np.linspace(0.30, 0.315, 41)

# Half flux
# phi_ext_sweep = np.linspace(0.48, 0.52, 41)

# Zero flux
# phi_ext_sweep = np.linspace(0, 0.1, 5)

# phi_ext_sweep = np.linspace(0, 1, 401)


vals_t = np.zeros([len(phi_ext_sweep), N_trunc])
vals_f = np.zeros([len(phi_ext_sweep), N_trunc])
vals_tot = np.zeros([len(phi_ext_sweep), N_trunc])
matrix_els = np.zeros([len(phi_ext_sweep), N_trunc])

# Simulate vs flux
for i, phi_ext in enumerate(phi_ext_sweep):
    # Transmon
    H_t, n_t, phi_t = get_transmon_AH(N_t, EC_s, EJ_t, EL)
    evals_t, evecs_t = H_t.eigenstates()
    # Fluxonium
    H_f, _, phi_f = get_fluxonium(N_f, EC_f, EJ_f, EL, phi_ext=phi_ext)
    evals_f, evecs_f = H_f.eigenstates()
    # Coupling
    coupling = EL * tensor(phi_t, phi_f)
    # Total hamiltonian
    H_tot = tensor(H_t, I_f) + tensor(I_t, H_f) + coupling
    evals_tot, evecs_tot = H_tot.eigenstates()

    # Eigenvalues
    vals_t[i, :] = (evals_t[:N_trunc] - evals_t[0]) / 2 / np.pi
    vals_f[i, :] = (evals_f[:N_trunc] - evals_f[0]) / 2 / np.pi
    vals_tot[i, :] = (evals_tot[:N_trunc] - evals_tot[0]) / 2 / np.pi

# %%
# path = r"Z:\Projects\BottomLoader\data\20251001_stormcrow_N17\2025-10-04\00193-cw_qubit_spectroscopy_vs_current_2025-10-04T020223"
# datadict = sqil.extract_h5_data(path, get_metadata=True)
# qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
# fig, axs = sqil.plot_mag_phase(datadict=datadict["q0"], transpose=True)

# Rough transmon scan
path0 = r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00131-cw_qubit_spectroscopy_vs_current_2025-10-03T000923"

paths = [
    # |10>
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00018-cw_qubit_spectroscopy_vs_current_2025-10-06T015830",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00258-cw_qubit_spectroscopy_vs_current_2025-10-04T165527",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00269-cw_qubit_spectroscopy_vs_current_2025-10-04T181446",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00279-cw_qubit_spectroscopy_vs_current_2025-10-04T203617",
    # |11>
    # r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00147-cw_qubit_spectroscopy_vs_current_2025-10-03T112955",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00019-cw_qubit_spectroscopy_vs_current_2025-10-06T033418",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00024-cw_qubit_spectroscopy_vs_current_2025-10-06T053057",
    # Anti-crossing
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00153-cw_qubit_spectroscopy_vs_current_2025-10-03T132052",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00193-cw_qubit_spectroscopy_vs_current_2025-10-04T020223",
    # Following |01> left
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00155-cw_qubit_spectroscopy_vs_current_2025-10-03T135806",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00156-cw_qubit_spectroscopy_vs_current_2025-10-03T141955",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00157-cw_qubit_spectroscopy_vs_current_2025-10-03T143339",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00158-cw_qubit_spectroscopy_vs_current_2025-10-03T144552",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00159-cw_qubit_spectroscopy_vs_current_2025-10-03T145823",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00162-cw_qubit_spectroscopy_vs_current_2025-10-03T153920",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00197-cw_qubit_spectroscopy_vs_current_2025-10-04T032851",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00201-cw_qubit_spectroscopy_vs_current_2025-10-04T042626",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00020-cw_qubit_spectroscopy_vs_current_2025-10-06T044529",
    # Following |01> right
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00225-cw_qubit_spectroscopy_vs_current_2025-10-04T111423",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00021-cw_qubit_spectroscopy_vs_current_2025-10-06T045542",
    # IDK
    # r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00240-cw_qubit_spectroscopy_vs_current_2025-10-04T122815",
    # r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00246-cw_qubit_spectroscopy_vs_current_2025-10-04T125214"
    # |20>
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00255-cw_qubit_spectroscopy_vs_current_2025-10-04T142932",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00023-cw_qubit_spectroscopy_vs_current_2025-10-06T051615",
]

datadict = sqil.extract_h5_data(path0, get_metadata=True)
qpu = sqil.read_qpu(path0, "qpu_old.json")
qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
fig, axs = sqil.plot_mag_phase(datadict=datadict["q0"], transpose=True)

for path in paths:
    datadict = sqil.extract_h5_data(path, get_metadata=True)
    qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
    sqil.plot_mag_phase(datadict=datadict["q0"], transpose=True, plot=(fig, axs))

axs[0].plot(phi_ext_sweep*(0.08765+0.025)*2 - 0.025, vals_tot[:,:6])
plt.show()

# %% [markdown]
# ### Fit

# %%
from scipy.optimize import minimize
from qutip import *

# Measured peaks at [-0.015, 0.020, 0.058, 0.0883, 0.1225, 0.140] mA
mvals = np.array(
    [
        [5.45002, 5.44261, 3.7639, np.nan, np.nan, 5.44261],
        [10.646, 8.4903, 5.4263, 5.4108, 5.4287, 6.6082],
        [np.nan, 10.627, np.nan, 5.48, 9.625, 10.6122],
        [np.nan, np.nan, 10.584, 10.542, 10.592, np.nan],
    ]
).T

x_data = np.array([-0.015, 0.020, 0.058, 0.0883, 0.1225, 0.140])

# %%
def simulate(x_data, EC_s, EJ_t, EC_f, EJ_f, EL):
    N_t, N_f = 15, 35
    I_t, I_f = qeye(N_t), qeye(N_f)
    N_trunc = 5

    phi_ext_sweep = (0.025 + x_data) / (0.08765 + 0.025) / 2

    vals_tot = np.zeros([len(phi_ext_sweep), N_trunc-1])
    # Simulate vs flux
    for i, phi_ext in enumerate(phi_ext_sweep):
        # Transmon
        H_t, _, phi_t = get_transmon_AH(N_t, EC_s, EJ_t, EL)
        # Fluxonium
        H_f, _, phi_f = get_fluxonium(N_f, EC_f, EJ_f, EL, phi_ext=phi_ext)
        # Coupling
        coupling = EL * tensor(phi_t, phi_f)
        # Total hamiltonian
        H_tot = tensor(H_t, I_f) + tensor(I_t, H_f) + coupling
        evals_tot = H_tot.eigenenergies()

        # Eigenvalues
        vals_tot[i, :] = (evals_tot[1:N_trunc] - evals_tot[0]) #/ 2 / np.pi

    return vals_tot


def cost(params):
    EC_s, EJ_t, EC_f, EJ_f, EL = params
    sim = simulate(x_data, EC_s, EJ_t, EC_f, EJ_f, EL)  # shape (n_points, n_modes)

    # Only compare the first few modes that exist in both sim and data
    n_modes = min(sim.shape[1], mvals.shape[1])
    sim = sim[:, :n_modes]
    meas = mvals[:, :n_modes]

    # Build a mask where measurement is valid
    mask = ~np.isnan(meas)
    err = meas[mask] - sim[mask]
    return np.sum(err**2)

# %%
p0 = [0.26, 14.66, 3.0, 20.0, 0.8]
bounds = [(0.255, 0.265), (12, 18), (2, 6), (12, 25), (0.1, 2.0)]

res = minimize(cost, p0, bounds=bounds, method="L-BFGS-B")
print("Best params:", res.x)
print("Final cost:", res.fun)

# %%
p0 = [0.26, 14.66, 3.2, 20.0, 0.8]
bounds = [
    (0.255, 0.265),
    (12, 18),
    (2, 6),
    (12, 25),
    (0.6, 1)
]

res = minimize(cost, p0, bounds=bounds, method="L-BFGS-B")
print("Best params:", res.x)
print("Final cost:", res.fun)
# Out:
# Best params: [ 0.25539058 15.08145857  2.07211333 20.14763693  0.79169325]
# Final cost: 0.02949738212332909

# %%
# Rough transmon scan
path0 = r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00131-cw_qubit_spectroscopy_vs_current_2025-10-03T000923"

paths = [
    # |10>
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00018-cw_qubit_spectroscopy_vs_current_2025-10-06T015830",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00258-cw_qubit_spectroscopy_vs_current_2025-10-04T165527",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00269-cw_qubit_spectroscopy_vs_current_2025-10-04T181446",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00279-cw_qubit_spectroscopy_vs_current_2025-10-04T203617",
    # |11>
    # r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00147-cw_qubit_spectroscopy_vs_current_2025-10-03T112955",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00019-cw_qubit_spectroscopy_vs_current_2025-10-06T033418",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00024-cw_qubit_spectroscopy_vs_current_2025-10-06T053057",
    # Anti-crossing
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00153-cw_qubit_spectroscopy_vs_current_2025-10-03T132052",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00193-cw_qubit_spectroscopy_vs_current_2025-10-04T020223",
    # Following |01> left
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00155-cw_qubit_spectroscopy_vs_current_2025-10-03T135806",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00156-cw_qubit_spectroscopy_vs_current_2025-10-03T141955",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00157-cw_qubit_spectroscopy_vs_current_2025-10-03T143339",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00158-cw_qubit_spectroscopy_vs_current_2025-10-03T144552",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00159-cw_qubit_spectroscopy_vs_current_2025-10-03T145823",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-03\00162-cw_qubit_spectroscopy_vs_current_2025-10-03T153920",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00197-cw_qubit_spectroscopy_vs_current_2025-10-04T032851",
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00201-cw_qubit_spectroscopy_vs_current_2025-10-04T042626",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00020-cw_qubit_spectroscopy_vs_current_2025-10-06T044529",
    # Following |01> right
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00225-cw_qubit_spectroscopy_vs_current_2025-10-04T111423",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00021-cw_qubit_spectroscopy_vs_current_2025-10-06T045542",
    # IDK
    # r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00240-cw_qubit_spectroscopy_vs_current_2025-10-04T122815",
    # r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00246-cw_qubit_spectroscopy_vs_current_2025-10-04T125214"
    # |20>
    r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-04\00255-cw_qubit_spectroscopy_vs_current_2025-10-04T142932",
    r"C:\Users\sqil\Desktop\data_local\20251005_stormcrow_N17\2025-10-06\00023-cw_qubit_spectroscopy_vs_current_2025-10-06T051615",
]

datadict = sqil.extract_h5_data(path0, get_metadata=True)
qpu = sqil.read_qpu(path0, "qpu_old.json")
qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
fig, axs = sqil.plot_mag_phase(datadict=datadict["q0"], transpose=True)

for path in paths:
    datadict = sqil.extract_h5_data(path, get_metadata=True)
    qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
    sqil.plot_mag_phase(datadict=datadict["q0"], transpose=True, plot=(fig, axs))


# x_fit = np.linspace(-0.025, 0.2016, 201)
x_fit = np.linspace(0.08, 0.09, 201)
y_fit = simulate(x_fit, *res.x)

colors = plt.rcParams["axes.prop_cycle"].by_key()["color"][1:]
# fig, ax = plt.subplots(figsize=(6, 8))

for j in range(mvals.shape[1]):
    y_meas = mvals[:, j]
    if np.all(np.isnan(y_meas)):
        continue  # skip if column is all NaNs
    # measured points
    axs[0].plot(x_data, y_meas, "o", color=colors[j % len(colors)], label=f"mode {j}")
    # simulated curve (if available for this mode)
    if j < y_fit.shape[1]:
        axs[0].plot(x_fit, y_fit[:, j], "-", color=colors[j % len(colors)])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[126], line 53
#      51 # x_fit = np.linspace(-0.025, 0.2016, 201)
#      52 x_fit = np.linspace(0.08, 0.09, 201)
# ---> 53 y_fit = simulate(x_fit, *res.x)
#      55 colors = plt.rcParams["axes.prop_cycle"].by_key()["color"][1:]
#      56 # fig, ax = plt.subplots(figsize=(6, 8))
#
# Cell In[15], line 19, in simulate(x_data, EC_s, EJ_t, EC_f, EJ_f, EL)
#      17 # Total hamiltonian
#      18 H_tot = tensor(H_t, I_f) + tensor(I_t, H_f) + coupling
# ---> 19 evals_tot = H_tot.eigenenergies()
#      21 # Eigenvalues
#      22 vals_tot[i, :] = (evals_tot[1:N_trunc] - evals_tot[0]) #/ 2 / np.pi
#
# File c:\Users\sqil\AppData\Local\pypoetry\Cache\virtualenvs\sqil-experiments-gl8RHkKX-py3.12\Lib\site-packages\qutip\core\qobj.py:1726, in Qobj.eigenenergies(self, sparse, sort, eigvals, tol, maxiter)
# ...

# %%
N_t, N_f = 15, 35
I_t, I_f = qeye(N_t), qeye(N_f)
N_trunc = 12

phi_ext_sweep = np.linspace(0, 1, 31) #(0.025 + x_data) / (0.08765 + 0.025) / 2

vals_tot = np.zeros([len(phi_ext_sweep), N_trunc-1])
# Simulate vs flux
for i, phi_ext in enumerate(phi_ext_sweep):
    # Transmon
    # H_t, _, phi_t = get_transmon_AH(N_t, EC_s, EJ_t, EL)
    # Fluxonium
    H_f, _, phi_f = get_fluxonium(N_f, EC_f, EJ_f, EL, phi_ext=phi_ext)
    # Coupling
    # coupling = EL * tensor(phi_t, phi_f)
    # Total hamiltonian
    # H_tot = tensor(H_t, I_f) + tensor(I_t, H_f) + coupling
    evals_tot = H_f.eigenenergies()

    # Eigenvalues
    vals_tot[i, :] = (evals_tot[1:N_trunc] - evals_tot[0]) / 2 / np.pi

plt.figure()
plt.plot(phi_ext_sweep, vals_tot)
plt.show()

# %%
plt.figure()
x_fit = np.linspace(-0.025, 0.2016, 101)
plt.plot(x_fit, simulate(x_fit, *res.x))
plt.show()

# %% [markdown]
# ### Test

# %%
from sqil_experiments.measurements.rr_spec import rr_spec_analysis

path = r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-02\00064-cw_resonator_spectroscopy_vs_current_2025-10-02T093557"

datadict = sqil.extract_h5_data(path, get_metadata=True)
qpu = sqil.read_qpu(path, "qpu_old.json")

anal_res = rr_spec_analysis(datadict=datadict, qpu=qpu)

# %%
def swap_axes_labels(axs):
    import numpy as np
    import matplotlib

    if not isinstance(axs, (list, np.ndarray)):
        axs = np.array([axs])  # make it iterable

    axs = np.array(axs).reshape(-1)  # flatten in case it's a 2D array

    for ax in axs:
        # Swap Line2D objects
        for line in ax.get_lines():
            x, y = line.get_xdata(), line.get_ydata()
            line.set_xdata(y)
            line.set_ydata(x)

        # Swap QuadMesh (pcolormesh)
        for quad in list(ax.collections):
            if isinstance(quad, matplotlib.collections.QuadMesh):
                try:
                    Z = quad.get_array().data
                    Z_swapped = Z.T if Z.ndim == 2 else Z

                    coords = quad._coordinates
                    x = coords[..., 0][0, :]  # original x
                    y = coords[..., 1][:, 0]  # original y

                    quad.remove()

                    ax.pcolormesh(
                        y, x, Z_swapped, shading="auto", cmap=quad.cmap, norm=quad.norm
                    )

                    ax.set_xlim(y.min(), y.max())
                    ax.set_ylim(x.min(), x.max())

                except Exception as e:
                    print("Error during QuadMesh swap:", e)

    # 🔄 Now handle label swapping and visibility logic
    # We do this in a second loop to make it layout-aware

    for ax in axs:
        # Get subplot position in the grid
        try:
            ss = ax.get_subplotspec()
            row, col = ss.rowspan.start, ss.colspan.start
            is_bottom = ss.rowspan.stop == ss.get_gridspec().nrows
            is_left = ss.colspan.start == 0
        except Exception:
            # fallback for non-gridspec plots
            is_bottom = True
            is_left = True

        # Swap labels
        xlabel = ax.get_xlabel()
        ylabel = ax.get_ylabel()
        ax.set_xlabel(ylabel if is_bottom else "")
        ax.set_ylabel(xlabel if is_left else "")

        ax.figure.canvas.draw()

swap_axes_labels(anal_res.figures["q0_fig"].axes)

plt.show()

# %%
import numpy as np
import matplotlib


import numpy as np
import matplotlib


def debug_swap_axes_labels(axs):
    if not isinstance(axs, (list, np.ndarray)):
        axs = [axs]

    for ax in axs:
        print("\n--- New Axes ---")
        # Lines (if any)
        for line in ax.get_lines():
            x, y = line.get_xdata(), line.get_ydata()
            print("Line: x.shape, y.shape:", x.shape, y.shape)
            line.set_xdata(y)
            line.set_ydata(x)

        # QuadMesh / pcolormesh
        for quad in list(ax.collections):  # convert to list, since we may remove items
            if isinstance(quad, matplotlib.collections.QuadMesh):
                try:
                    Z = quad.get_array().data
                    print("Original Z.shape:", Z.shape)
                    Z_swapped = Z.T if Z.ndim == 2 else Z
                    print("Swapped Z.shape:", Z_swapped.shape)

                    coords = quad._coordinates
                    print("Coordinates array shape:", coords.shape)
                    # coords is shape (ny, nx, 2) or something
                    # get x and y arrays if possible
                    x = coords[..., 0][0, :]  # first row, all columns
                    y = coords[..., 1][:, 0]  # all rows, first column
                    print("Extracted x (orig):", x[:5], "...", x[-5:])
                    print("Extracted y (orig):", y[:5], "...", y[-5:])
                    print("x.min, x.max:", x.min(), x.max())
                    print("y.min, y.max:", y.min(), y.max())

                    quad.remove()

                    # Re-plot
                    new_quad = ax.pcolormesh(
                        y, x, Z_swapped, shading="auto", cmap=quad.cmap, norm=quad.norm
                    )
                    print(
                        "After plotting swapped: new_quad coords shape:",
                        new_quad._coordinates.shape,
                    )
                    print(
                        "New _coordinates first row (x coords):",
                        new_quad._coordinates[0, :5, 0],
                    )
                    print(
                        "New _coordinates first col (y coords):",
                        new_quad._coordinates[:5, 0, 1],
                    )

                except Exception as e:
                    print("Error during QuadMesh swap:", e)

        # Swap labels
        xlabel = ax.get_xlabel()
        ylabel = ax.get_ylabel()
        ax.set_xlabel(ylabel)
        ax.set_ylabel(xlabel)

        # Swap limits
        xlim = ax.get_xlim()
        ylim = ax.get_ylim()
        print("Before swap: xlim, ylim:", xlim, ylim)
        ax.set_xlim(ylim)
        ax.set_ylim(xlim)
        print("After swap limits: xlim, ylim:", ax.get_xlim(), ax.get_ylim())

        ax.figure.canvas.draw()


def swap_axes_labels(axs):
    import numpy as np
    import matplotlib

    if not isinstance(axs, (list, np.ndarray)):
        axs = [axs]

    for ax in axs:
        # Swap Line2D objects
        for line in ax.get_lines():
            x, y = line.get_xdata(), line.get_ydata()
            line.set_xdata(y)
            line.set_ydata(x)

        # Swap QuadMesh (pcolormesh)
        for quad in list(ax.collections):
            if isinstance(quad, matplotlib.collections.QuadMesh):
                try:
                    Z = quad.get_array().data
                    Z_swapped = Z.T if Z.ndim == 2 else Z

                    coords = quad._coordinates
                    x = coords[..., 0][0, :]  # original x
                    y = coords[..., 1][:, 0]  # original y

                    quad.remove()

                    # Re-plot with swapped axes
                    ax.pcolormesh(
                        y, x, Z_swapped, shading="auto", cmap=quad.cmap, norm=quad.norm
                    )

                    # Set correct new axis limits
                    ax.set_xlim(y.min(), y.max())  # x is now y
                    ax.set_ylim(x.min(), x.max())  # y is now x

                except Exception as e:
                    print("Error during QuadMesh swap:", e)

        # Swap axis labels
        xlabel = ax.get_xlabel()
        ylabel = ax.get_ylabel()
        ax.set_xlabel(ylabel)
        ax.set_ylabel(xlabel)

        ax.figure.canvas.draw()


# Usage
# fig, axs = plot_mag_phase(datadict=datadict)
swap_axes_labels(anal_res.figures["q0_fig"].axes)

plt.show()

# %%
from sqil_core.utils import *

def plot_mag_phase(path=None, datadict=None, raw=False):
    """
    Plot the magnitude and phase of complex measurement data from an db path or
    in-memorydictionary.

    This function generates either a 1D or 2D plot of the magnitude and phase of complex
    data, depending on the presence of sweep parameters. It supports normalization and
    background subtraction.

    Parameters
    ----------
    path : str or None, optional
        Path to the folder containing measurement data. Required if `datadict` is not
        provided.
    datadict : dict or None, optional
        Pre-loaded data dictionary with schema, typically extracted using
        `extract_h5_data`.
        Required if `path` is not provided.
    raw : bool, default False
        If True, skip normalization and background subtraction for 2D plots. Useful for
        viewing raw data.

    Returns
    -------
    fig : matplotlib.figure.Figure
        The matplotlib Figure object containing the plot.
    axs : matplotlib.axes.Axes or ndarray of Axes
        The Axes object(s) used for the subplot(s).

    Raises
    ------
    Exception
        If neither `path` nor `datadict` is provided.

    Notes
    -----
    - Axes and units are automatically inferred from the schema in the dataset.
    """

    all_data, all_info, _ = get_data_and_info(path=path, datadict=datadict)
    x_data, y_data, sweeps = all_data
    x_info, y_info, sweep_info = all_info

    # Rescale data
    x_data_scaled = x_data * x_info.scale
    y_data_scaled = y_data * y_info.scale
    y_unit = f" [{y_info.rescaled_unit}]" if y_info.unit else ""

    set_plot_style(plt)

    if len(sweeps) == 0:  # 1D plot
        fig, axs = plt.subplots(2, 1, figsize=(20, 12), sharex=True)

        axs[0].plot(x_data_scaled, np.abs(y_data_scaled), "o")
        axs[0].set_ylabel("Magnitude" + y_unit)
        axs[0].tick_params(labelbottom=True)
        axs[0].xaxis.set_tick_params(
            which="both", labelbottom=True
        )  # Redundant for safety

        axs[1].plot(x_data_scaled, np.unwrap(np.angle(y_data_scaled)), "o")
        axs[1].set_xlabel(x_info.name_and_unit)
        axs[1].set_ylabel("Phase [rad]")
    else:  # 2D plot
        fig, axs = plt.subplots(1, 2, figsize=(24, 12), sharex=True, sharey=True)

        # Process mag and phase
        mag, phase = np.abs(y_data), np.unwrap(np.angle(y_data))
        if not raw:
            mag = soft_normalize(remove_offset(mag))
            flat_phase = remove_linear_background(x_data, phase, points_cut=1)
            phase = soft_normalize(flat_phase)
        # Load sweep parameter
        sweep0_info = sweep_info[0]
        sweep0_scaled = sweeps[0] * sweep0_info.scale

        c0 = axs[0].pcolormesh(
            x_data_scaled, sweep0_scaled, mag, shading="auto", cmap="PuBu"
        )
        if raw:
            fig.colorbar(c0, ax=axs[0])
            axs[0].set_title("Magnitude" + y_unit)
        else:
            axs[0].set_title("Magnitude (normalized)")
        axs[0].set_xlabel(x_info.name_and_unit)
        axs[0].set_ylabel(sweep0_info.name_and_unit)

        c1 = axs[1].pcolormesh(
            x_data_scaled, sweep0_scaled, phase, shading="auto", cmap="PuBu"
        )
        if raw:
            fig.colorbar(c1, ax=axs[1])
            axs[1].set_title("Phase [rad]")
        else:
            axs[1].set_title("Phase (normalized)")
        axs[1].set_xlabel(x_info.name_and_unit)
        axs[1].tick_params(labelleft=True)
        axs[1].xaxis.set_tick_params(
            which="both", labelleft=True
        )  # Redundant for safety

    fig.tight_layout()
    return fig, axs


path = r"C:\Users\sqil\Desktop\data_local\20251001_stormcrow_N17\2025-10-02\00064-cw_resonator_spectroscopy_vs_current_2025-10-02T093557"

datadict = sqil.extract_h5_data(path, get_metadata=True)
qpu = sqil.read_qpu(path, "qpu_old.json")

plot_mag_phase(datadict=datadict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 113
#     110 datadict = sqil.extract_h5_data(path, get_metadata=True)
#     111 qpu = sqil.read_qpu(path, "qpu_old.json")
# --> 113 plot_mag_phase(path=path)
#
# Cell In[13], line 43, in plot_mag_phase(path, datadict, raw)
#       4 """
#       5 Plot the magnitude and phase of complex measurement data from an db path or
#       6 in-memorydictionary.
#    (...)     39 - Axes and units are automatically inferred from the schema in the dataset.
#      40 """
#      42 all_data, all_info, _ = get_data_and_info(path=path, datadict=datadict)
# ---> 43 x_data, y_data, sweeps = all_data
#      44 x_info, y_info, sweep_info = all_info
#      46 # Rescale data
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %% [markdown]
# # TD

# %% [markdown]
# ### Stiching

# %%
# Rough transmon scan
path0 = r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-07\00104-qubit_spectroscopy_vs_current_2025-10-07T023338"

paths = [
    # |10>
    # |11>
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-07\00105-qubit_spectroscopy_vs_current_2025-10-07T035837",
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-12\00816-qubit_spectroscopy_vs_current_2025-10-12T040820",
    # |01>
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-07\00106-qubit_spectroscopy_vs_current_2025-10-07T044306",
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-07\00107-qubit_spectroscopy_vs_current_2025-10-07T045435",
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-12\00817-qubit_spectroscopy_vs_current_2025-10-12T041640",
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-12\00818-qubit_spectroscopy_vs_current_2025-10-12T042459",
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-12\00819-qubit_spectroscopy_vs_current_2025-10-12T043319",
    # Anti-crossing
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-11\00668-qubit_spectroscopy_vs_current_2025-10-11T034016",
    # Half-flux transmon
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-11\00670-qubit_spectroscopy_vs_current_2025-10-11T045954",
    # Transmon 02/2
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-11\00669-qubit_spectroscopy_vs_current_2025-10-11T043118",
    # Transmon 01
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-12\00727-qubit_spectroscopy_vs_current_2025-10-12T011205",
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-12\00728-qubit_spectroscopy_vs_current_2025-10-12T012350",
    # Wide range
    r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-12\00825-qubit_spectroscopy_vs_current_2025-10-12T142504",
]

datadict = sqil.extract_h5_data(path0, get_metadata=True)
qpu = sqil.read_qpu(path0, "qpu_old.json")
qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
fig, axs = sqil.plot_mag_phase(datadict=datadict["q0"], transpose=True)

for path in paths:
    datadict = sqil.extract_h5_data(path, get_metadata=True)
    qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
    sqil.plot_mag_phase(datadict=datadict["q0"], transpose=True, plot=(fig, axs))

fig.show()

# %%
10 + 20 * np.log10(0.8)
# Out:
# np.float64(8.061799739838872)

# %% [markdown]
# ### Fit

# %%
from sqil_experiments.analysis.fit import find_shared_peak
from sqil_core.utils import *

# %%
# %matplotlib qt
path = r"C:\Users\sqil\Desktop\data_local\20251006_stormcrow_N17\2025-10-07\00104-qubit_spectroscopy_vs_current_2025-10-07T023338"

datadict = sqil.extract_h5_data(path, get_metadata=True)
qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
qu_data, qu_info, datadict = qu_data["q0"], qu_info["q0"], datadict["q0"]
freq, data, sweeps = qu_data
curr = sweeps[0]

fig, axs = sqil.plot_mag_phase(datadict=datadict, transpose=True)

# freq_mask = freq[0] > 5.475e9
# curr_mask = (curr > 43.7e-6) & (curr < 45.5e-6)
# freq = freq[np.ix_(curr_mask, freq_mask)]
# data = data[np.ix_(curr_mask, freq_mask)]
# curr = curr[curr_mask]

y_fit = np.zeros(len(data))
for i in range(len(data)):
    f  = freq[i]
    mag, phase = np.abs(data[i]), np.angle(data[i])
    try:
        fit_res = find_shared_peak(f, mag, phase)
        if not fit_res or not fit_res.is_acceptable():
            y_fit[i] = np.nan
            continue
        y_fit[i] = fit_res.params_by_name['x0']
    except:
        y_fit[i] = np.nan
    

axs[0].plot(curr * 1e3, y_fit * 1e-9, color='tab:red')
plt.show()

# %%
freq_mask = freq[0] < 5.48e9
curr_mask = curr < 44.5e-6
freq[np.ix_(curr_mask, freq_mask)]
# Out:
# array([[5.42000000e+09, 5.42033333e+09, 5.42066667e+09, ...,
#         5.47900000e+09, 5.47933333e+09, 5.47966667e+09],
#        [5.42000000e+09, 5.42033333e+09, 5.42066667e+09, ...,
#         5.47900000e+09, 5.47933333e+09, 5.47966667e+09],
#        [5.42000000e+09, 5.42033333e+09, 5.42066667e+09, ...,
#         5.47900000e+09, 5.47933333e+09, 5.47966667e+09],
#        ...,
#        [5.42000000e+09, 5.42033333e+09, 5.42066667e+09, ...,
#         5.47900000e+09, 5.47933333e+09, 5.47966667e+09],
#        [5.42000000e+09, 5.42033333e+09, 5.42066667e+09, ...,
#         5.47900000e+09, 5.47933333e+09, 5.47966667e+09],
#        [5.42000000e+09, 5.42033333e+09, 5.42066667e+09, ...,
#         5.47900000e+09, 5.47933333e+09, 5.47966667e+09]], shape=(61, 180))

# %%
y_fit
# Out:
# array([nan, nan, nan, ..., nan, nan, nan], shape=(1001,))

# %% [markdown]
# # 11-25

# %%
# Rough transmon scan
path0 = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-11-10\00089-qubit_spectroscopy_vs_current_2025-11-10T231742"

paths = [
    r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-11-12\00155-qubit_spectroscopy_vs_current_2025-11-12T051353",
    r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-11-14\00509-qubit_spectroscopy_vs_current_2025-11-14T233051",
    r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-11-15\00511-qubit_spectroscopy_vs_current_2025-11-15T104307",
    # |11>
    r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-11-10\00080-qubit_spectroscopy_vs_current_2025-11-10T143844",
    # Follow fluxonium
    r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-11-10\00083-qubit_spectroscopy_vs_current_2025-11-10T154846",
    r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-11-11\00092-qubit_spectroscopy_vs_current_2025-11-11T120700",
    r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-11-12\00154-qubit_spectroscopy_vs_current_2025-11-12T021632",

    
]

datadict = sqil.extract_h5_data(path0, get_metadata=True)
qpu = sqil.read_qpu(path0, "qpu_old.json")
qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
fig, axs = sqil.plot_mag_phase(datadict=datadict["q0"], transpose=True)

for path in paths:
    datadict = sqil.extract_h5_data(path, get_metadata=True)
    qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)
    sqil.plot_mag_phase(datadict=datadict["q0"], transpose=True, plot=(fig, axs))

fig.show()

# %%
path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-11-14\00509-qubit_spectroscopy_vs_current_2025-11-14T233051"

datadict = sqil.extract_h5_data(path, get_metadata=True)
qpu = sqil.read_qpu(path, "qpu_old.json")

anal_res = qu_spec_analysis(datadict=datadict, qpu=qpu)

def threshold_normalize(fig, threshold):
    ax = fig.axes[0]
    quadmesh = ax.collections[0]

    # Extract the data as a flat array
    Z_flat = quadmesh.get_array()
    # Get number of x and y cells
    nx = len(quadmesh._coordinates[0]) - 1
    ny = len(quadmesh._coordinates) - 1
    # Reshape back to 2D
    Z = Z_flat.reshape(ny, nx)

    # Re-normalize
    Z_processed = np.where(Z > threshold, 1, Z)
    # Update the QuadMesh with new flattened data
    quadmesh.set_array(Z_processed.ravel())

    # Redraw
    fig.canvas.draw_idle()

    return fig

threshold_normalize(anal_res.figures["q0_fig"], 0.1)
plt.show()

# %% [markdown]
# #### Plot latest 2D and line cuts

# %%
path = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2026-01-06\11681-qubit_spectroscopy_vs_index_2026-01-06T134840"
datadict = sqil.extract_h5_data(path, get_metadata=True)

qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)

y, z, x =  qu_data['q0']
x = np.array(x).reshape(-1)
plt.figure()
if len(x) > 0:
    # plt.pcolormesh( x, y[0,:], abs(z.T)  )
    plt.pcolormesh(y[0,:], x, abs(z)  )
    # plt.pcolormesh(y[0,:], x, np.angle(z)  )
    # plt.pcolormesh( x, y[0,:], np.angle(z.T)  )
    # plt.pcolormesh( x, y[0,:], (z.T).imag  )
else:
    plt.plot( y, np.abs(z)  )
plt.show()

# %%
import sqil_core as sqil
from sqil_experiments.measurements.T1 import analyze_T1

parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2026-01-03\\"
import os
paths = [f for f in os.listdir(parent_path) ]
path = paths[np.argmax(paths)     ]
# path = [x for x in paths if '06104' in x][0]
datadict = sqil.extract_h5_data(parent_path+ path, get_metadata=True)

plt.figure()
qu_data, qu_info, datadict = sqil.get_data_and_info(datadict=datadict)

y, z, x =  qu_data['q0']
x = np.array(x).reshape(-1)
# plt.pcolormesh(y[0,:], x, abs(z)  )
# plt.pcolormesh(y[0,:], x, abs(z) -abs(z)[:,0][:,np.newaxis] )
plt.pcolormesh(y[0,:], x, np.angle(z)  )
# plt.pcolormesh(y[0,:], x, np.angle(z)   -np.angle(z)[:,0][:,np.newaxis]   )
# z_new = np.angle(z)   -np.angle(z)[:,0][:,np.newaxis]
# z_new[np.unravel_index(np.argsort(z_new.reshape(-1))[:10], z_new.shape)] = z_new.mean()
# plt.pcolormesh(y[0,:], x,  z_new  )

# x = np.array(datadict['q0']['sweep0'])
# z = ( datadict['q0']['data_g'],  datadict['q0']['data_e'] )
# y = datadict['q0']['readout_resonator_frequency']
# plt.pcolormesh(y, x, abs(  z[0]  )  )
# y = ( datadict['q0']['data_g'],  datadict['q0']['data_e'] )
# x = datadict['q0']['readout_resonator_frequency']
# plt.plot(x, abs(y[0])  )
# plt.plot(x, abs(y[1])  )
plt.show()
plt.title(path)
# Out:
# Text(0.5, 1.0, '11531-T1_vs_index_2026-01-03T224944')

# %%
0.0018/0.034
# Out:
# 0.05294117647058823

# %%
T = 0.08
p_g_r = 1
p_e_r = p_g_r * np.exp(-5e9*6.62e-34/(1.38e-23*T))
print( p_e_r/(p_e_r + p_g_r)  )
# Out:
# 0.04750778208557034

# %%
np.unravel_index(flat_idx, a.shape)

# %%
_, zdata, xdata =  qu_data['q0']
xdata = xdata[0]
ydata = np.average(zdata, axis=1) 
plt.figure()
plt.plot(xdata, np.abs(ydata))
plt.show()

# %%
plt.figure()

# for yval in [  7.7272e9, 7.7273e9, 7.7274e9, 7.7275e9 ]: 
#     yid = np.argmin(abs(y[0,:]-yval))
#     plt.plot(x, np.abs(z) [:,yid] ,label=f'yval={y[0,yid]:.5g}' )
    # plt.plot(x, (z).imag [:,yid] ,label=f'yval={y[0,yid]:.5g}' )

for xid in range(20, 30): 
    plt.plot(y[0,:], np.angle(z) [xid,:] ,label=f'xval={x[xid]:.5g}' )
    # plt.plot(y[0,:], np.angle(z) [xid,:] ,label=f'xval={x[xid]:.5g}' )
plt.legend()
plt.show()

# %%
plt.figure()

# for yval in [  7.7272e9, 7.7273e9, 7.7274e9, 7.7275e9 ]: 
#     yid = np.argmin(abs(y[0,:]-yval))
#     plt.plot(x, np.abs(z) [:,yid] ,label=f'yval={y[0,yid]:.5g}' )
    # plt.plot(x, (z).imag [:,yid] ,label=f'yval={y[0,yid]:.5g}' )

for xval in [ 7.4228e9,  7.4230e9,  7.4232e9,   7.4234e9 ]: 
    xid = np.argmin(abs(x-xval))
    plt.plot(y[0,:], np.angle(z) [xid,:] ,label=f'xval={x[xid]:.5g}' )
    # plt.plot(y[0,:], np.angle(z) [xid,:] ,label=f'xval={x[xid]:.5g}' )
plt.legend()
plt.show()

# %%
plt.figure()
plt.scatter( 0, 0, c='k' )
plt.scatter(  z[0,0].real, z[0,0].imag )

max_id = np.argmax(np.angle(z) [0,:])
plt.scatter(  z[0,max_id].real, z[0,max_id].imag )
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(5,5))

path_rabi = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-22\06024-time_rabi_2025-12-22T100926"
data_rabi = sqil.extract_h5_data(path_rabi, ["q0/data"])  
ax.plot(data_rabi.real, data_rabi.imag, 'o', c='C0', label="transmon Rabi")
ax.plot(data_rabi[0].real, data_rabi[0].imag, 'x', c='C0', markersize=10  )

path_rabi = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-22\06034-time_rabi_2025-12-22T112949"
path_rabi = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-22\06042-time_rabi_2025-12-22T141606"
data_rabi = sqil.extract_h5_data(path_rabi, ["q0/data"])  
ax.plot(data_rabi.real, data_rabi.imag, 'o', c='C1', label="fluxonium Rabi")
ax.plot(data_rabi[0].real, data_rabi[0].imag, 'x', c='C1', markersize=10 )

path_ = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-22\06041-qubit_spectroscopy_hdawg_2025-12-22T141420"
path_ = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-22\06043-qubit_spectroscopy_hdawg_2025-12-22T141907"
data_ = sqil.extract_h5_data(path_, ["q0/data"])  
ax.plot(data_.real, data_.imag, 'o', c='C2', label="")
ax.plot(data_[0].real, data_[0].imag, 'x', c='C2', markersize=10, label="")


ax.axis('equal')
ax.grid(True)
ax.legend()
plt.show()

# %% [markdown]
# ##### 06078, 06081, T1 Rabi  IQ

# %%
fig, ax = plt.subplots(1,1, figsize=(5,5))

path_rabi = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-24\06078-time_rabi_2025-12-24T105107"
data_rabi = sqil.extract_h5_data(path_rabi, ["q0/data"])  
ax.plot(data_rabi.real, data_rabi.imag, 'o', c='C0', label="Rabi")
ax.plot(data_rabi[0].real, data_rabi[0].imag, 'x', c='C0', markersize=10  )

path_ = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-24\06081-T1_hdawg_2025-12-24T105202"
data_ = sqil.extract_h5_data(path_, ["q0/data"])  
ax.plot(data_.real, data_.imag, 'o', c='C1', label="long")
ax.plot(data_[0].real, data_[0].imag, 'x', c='C1', markersize=10, label="")

# path_ = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-24\06085-T1_hdawg_vs_index_2025-12-24T111629"
# data_ = sqil.extract_h5_data(path_, ["q0/data"]) [0,:] 
# ax.plot(data_.real, data_.imag, 'o', c='C2', label="short")
# ax.plot(data_[0].real, data_[0].imag, 'x', c='C2', markersize=10, label="")
# print(sqil.extract_h5_data(path_, ["q0/time"]))


path_ = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-24\06083-T1_hdawg_2025-12-24T111256"
data_ = sqil.extract_h5_data(path_, ["q0/data"])  
ax.plot(data_.real, data_.imag, 'o', c='C2', label="long")

path_  = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-24\06079-T1_hdawg_2025-12-24T105139"
data_ = sqil.extract_h5_data(path_, ["q0/data"])  
ax.plot(data_.real, data_.imag, '^', c='C2', label="long")

path_ = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-24\06084-T1_hdawg_2025-12-24T111307"
data_ = sqil.extract_h5_data(path_, ["q0/data"])  
ax.plot(data_.real, data_.imag, 'o', c='C3', label="long")

path_  = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-24\06080-T1_hdawg_2025-12-24T105151"
data_ = sqil.extract_h5_data(path_, ["q0/data"])  
ax.plot(data_.real, data_.imag, '^', c='C3', label="long")

# ax.axis('equal')
ax.grid(True)
ax.legend()
plt.show()

# %% [markdown]
# ##### 06106-06112  T1, Rabi, IQ

# %%
parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-12-24\\"
import os
paths = [f for f in os.listdir(parent_path) ]

fig, ax = plt.subplots(1,1, figsize=(5,5))


path_rabi = [x for x in paths if '06106' in x][0]
data_rabi = sqil.extract_h5_data(parent_path+path_rabi, ["q0/data"])  
ax.plot(data_rabi.real, data_rabi.imag, 'o', c='C0', label="Rabi")
ax.plot(data_rabi[0].real, data_rabi[0].imag, 'x', c='C0', markersize=10  )

path_ = [x for x in paths if '06107' in x][0]
data_ = sqil.extract_h5_data(parent_path+path_, ["q0/data"])   
ax.plot(data_.real, data_.imag, 'o', c='C1', label="short T1")

path_ = [x for x in paths if '06108' in x][0]
data_ = sqil.extract_h5_data(parent_path+path_, ["q0/data"])   
ax.plot(data_.real, data_.imag, 'o', c='C2', label="short T1")

path_ = [x for x in paths if '06109' in x][0]
data_ = sqil.extract_h5_data(parent_path+path_, ["q0/data"])  
ax.plot(data_.real, data_.imag, 'o', c='r', label="long T1 init e")
ax.plot(data_[0].real, data_[0].imag, 'x', c='r', markersize=15, label="")

path_ = [x for x in paths if '06110' in x][0]
data_ = sqil.extract_h5_data(parent_path+path_, ["q0/data"])  
ax.plot(data_.real, data_.imag, 'o', c='b', label="long T1 init g")
ax.plot(data_[0].real, data_[0].imag, 'x', c='b', markersize=15, label="")


path_ = [x for x in paths if '06111' in x][0]
data_ = sqil.extract_h5_data(parent_path+path_, ["q0/data"])  
ax.plot(data_.real, data_.imag, '^', c='C1', label="short T1")

path_ = [x for x in paths if '06112' in x][0]
data_ = sqil.extract_h5_data(parent_path+path_, ["q0/data"])  
ax.plot(data_.real, data_.imag, '^', c='C2', label="short T1")

# ax.axis('equal')
ax.grid(True)
ax.legend()
plt.show()

# %% [markdown]
# ##### 06139-06246 T1 files check IQ

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib qt
import os
import sqil_core as sqil
from sqil_experiments.measurements.T1 import analyze_T1
from sqil_experiments.measurements.qu_spec import qu_spec_analysis

parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-12-24\\"

paths = [f for f in os.listdir(parent_path) ]
start_id, end_id = '06139', '06246'

start, end = [i for i in range(len(paths)) if start_id in paths[i] or end_id in paths[i]]
paths_select = paths[start:end+1]

id_T1 = [i for i in range(len(paths_select)) if 'T1_hdawg' in paths_select[i] ]
id_freq_ = [i for i in range(len(paths_select)) if 'qubit_spectroscopy_hdawg' in paths_select[i] ]

id_freq = np.zeros_like(id_T1, dtype=int)
for i in range(len(id_T1)):
    id_freq[i] = id_freq_[np.where( np.array(id_freq_) < id_T1[i] )[0][-1]  ]

pi_time = []
for i in range(len(id_T1)//2):
    fig, ax = plt.subplots(1,1, figsize=(5,5))
    data = sqil.extract_h5_data(parent_path+paths_select[id_freq[i*2]], ["q0/data"]) 
    ax.plot(data.real, data.imag, 'o', c='C0', label="spec ")
    ax.plot(data[0].real, data[0].imag, 'x', c='C0', markersize=15  )      


    if 'time_rabi' in paths_select[id_freq[i*2]+1]:
        data = sqil.extract_h5_data(parent_path+paths_select[id_freq[i*2]+1], ["q0/data"]) 
        ax.plot(data.real, data.imag, 'o', c='C1', label="rabi ")
        ax.plot(data[0].real, data[0].imag, 'x', c='C1', markersize=15  )  
        f_hdawg = sqil.read_qpu(parent_path+paths_select[id_freq[i*2]+1], "qpu_old.json").quantum_elements[0].parameters.resonance_frequency_hdawg
        Tpi = sqil.read_qpu(parent_path+paths_select[id_freq[i*2]+1], "qpu_new.json").quantum_elements[0].parameters.hdawg_drive_length
        pi_time += [   [f_hdawg, Tpi  ]  ,   ]
    data = sqil.extract_h5_data(parent_path+paths_select[id_T1[i*2]], ["q0/data"]) 
    ax.plot(data.real, data.imag, 'o', c='C2', label="T1 short ")
    ax.plot(data[0].real, data[0].imag, 'x', c='C2', markersize=15  )

    data = sqil.extract_h5_data(parent_path+paths_select[id_T1[i*2+1]], ["q0/data"]) 
    ax.plot(data.real, data.imag, 'o', c='C3', label="T1 long")
    ax.plot(data[0].real, data[0].imag, 'x', c='C3', markersize=15  )           
    ax.grid(True)
    ax.legend()
    plt.show()
pi_time = np.array(pi_time)

# %%
paths_select[id_T1[8*2]]
# Out:
# '06200-T1_hdawg_2025-12-24T193616'

# %%
pi_time
# Out:
# array([[9.81782996e+07, 1.84130518e-07],
#        [9.58691651e+07, 1.81404822e-07],
#        [1.09041345e+08, 1.95056111e-07],
#        [1.33714294e+08, 2.17962610e-07],
#        [1.64170254e+08, 2.17378037e-07],
#        [1.98015110e+08, 2.30015765e-07],
#        [2.33951594e+08, 2.66816306e-07],
#        [2.71252903e+08, 2.81289361e-07],
#        [3.09008158e+08, 3.16331754e-07],
#        [3.47475797e+08, 3.53330570e-07],
#        [4.25187688e+08, 4.64785496e-07],
#        [4.64514834e+08, 4.85329497e-07]])

# %%
plt.figure()
plt.plot(pi_time[:,0], pi_time[:,1])
plt.show()

coeffs = np.polyfit(pi_time[:,0], pi_time[:,1],deg=1)

plt.plot(pi_time[:,0], np.poly1d(coeffs)(pi_time[:,0])  )

# %%
coeffs
# Out:
# array([8.01354837e-16, 9.24721244e-08])

# %%
coeffs[0]*95e6 + coeffs[1]
# Out:
# np.float64(1.6860083392325055e-07)

# %%
plt.figure()
plt.plot( np.log(pi_time[:,0]), np.log(pi_time[:,1])    )
plt.show()

# %% [markdown]
# #### Plot latest 1d and single-shot window average

# %%
from sqil_experiments.measurements.T1 import analyze_T1

parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-12-22\\"
import os
paths = [f for f in os.listdir(parent_path) ]
# path = paths[np.argmax(paths)  ]
path = [x for x in paths if '06036' in x][0]
datadict = sqil.extract_h5_data(parent_path+ path, get_metadata=True)

z = datadict['q0']['data']
y = datadict['q0']['frequencies']

plt.figure()
# plt.plot( y, np.mean(np.angle(z),axis=0)  )
# plt.plot( y, np.mean(np.abs(z),axis=0)  )
plt.plot( y, np.angle(z )    )
# plt.plot( y, np.abs(np.mean(z,axis=0) )    )

# plt.pcolormesh( x, y, np.angle(z).T  )
plt.show()

# %%
parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-12-22\\"
f_id = '06036'

parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-12-23\\"
f_id = '06051'
f_id = '06054'

parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-12-24\\"
f_id = '06059'
import os
paths = [f for f in os.listdir(parent_path) ]
# path = paths[np.argmax(paths)  ]
path = [x for x in paths if f_id in x][0]

datadict = sqil.extract_h5_data(parent_path+ path, get_metadata=True)

z = datadict['q0']['data'][0,:,:]
y = datadict['q0']['frequencies'].reshape(-1)
x = np.arange(z.shape[0])
# plt.figure()
# plt.pcolormesh( x, y, np.angle(z).T  )
# plt.show()

import scipy
N_avg = 100
kernel_avg = np.ones((N_avg,1))/(N_avg)
z_avg = scipy.signal.convolve2d( kernel_avg, z, mode='valid', )
x_avg = x[N_avg//2:-N_avg//2+1]
# plt.figure()
# plt.pcolormesh( x_avg, y, np.angle(z_avg).T  )
# plt.show()

z_ds = z[:len(z)//N_avg * N_avg].reshape(-1, N_avg, z.shape[1]).mean(axis=1)
x_ds = x[::N_avg]
plt.figure()
plt.pcolormesh( x_ds, y, np.angle(z_ds).T  )
plt.show()

# %%
parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-12-23\\"
f_id = '06057'
f_id = '06058'
parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-12-24\\"
f_id = '06067'
f_id = '06072'
# f_id = '06073'
import os
paths = [f for f in os.listdir(parent_path) ]
# path = paths[np.argmax(paths)  ]
path = [x for x in paths if f_id in x][0]
datadict = sqil.extract_h5_data(parent_path+ path, get_metadata=True)

sweep0 = datadict['q0']['sweep0']
z = np.vstack( [datadict['q0']['data'][i,:,:] for i in sweep0]  )
y = datadict['q0']['frequencies'][0,:]
x = np.arange(z.shape[0])

def clip_and_inpaint(z, vmin, vmax):
    z = z.copy()
    ny, nx = z.shape
    def neighbors(i, j):
        for di, dj in [(-1,0),(1,0),(0,-1),(0,1)]:
            ni, nj = i + di, j + dj
            if 0 <= ni < ny and 0 <= nj < nx:
                yield ni, nj
    mask = (np.abs(z) < vmin) | (np.abs(z) > vmax)
    for i, j in np.argwhere(mask):
        vals = []
        for ni, nj in neighbors(i, j):
            if vmin <= np.abs(z[ni, nj]) <= vmax:
                vals.append(z[ni, nj])
        if vals:  # assumed to exist
            z[i, j] = np.mean(vals)
    return z

N_avg = 50

z_ds = z[:len(z)//N_avg * N_avg].reshape(-1, N_avg, z.shape[1]).mean(axis=1)
x_ds = x[::N_avg]
plt.figure(figsize=(15,6))
# plt.pcolormesh( x_ds, y, clip_and_inpaint(np.angle(z_ds).T  , -2.5, 1   )  )
plt.pcolormesh( x_ds, y, np.angle(z_ds).T  )
plt.show()

# %%
plt.figure()
plt.hist( np.angle(z_ds.ravel()), bins=100, color='skyblue', edgecolor='black')
plt.show()

# %%
import matplotlib.dates as mdates
import datetime
start_path = parent_path + path + r'\qpu_old.json'
start_time=datetime.datetime.fromtimestamp(os.path.getmtime(start_path))
end_path = parent_path + path + r'\data.ddh5'
end_time=datetime.datetime.fromtimestamp(os.path.getmtime(end_path))

shot_count = 10000
time_list = np.linspace( start_time, end_time, len(x_ds))
index_list = np.arange( len(x_ds), dtype=int) * N_avg

fig, axs = plt.subplots(1,1,figsize=(15,6))

ax = axs
ax.pcolormesh( time_list, y, np.angle(z_ds).T  )


max_labels = 10
step = max(1, len(index_list) // max_labels)
tick_positions = mdates.date2num(time_list[::step])
tick_labels = index_list[::step]
secax = ax.secondary_xaxis('top')
secax.set_xticks(tick_positions)
secax.set_xticklabels(tick_labels)

# ax.axvline( datetime.datetime.strptime('2025-12-23/23:43:00', '%Y-%m-%d/%H:%M:%S'), c='r')
# ax.axvline( datetime.datetime.strptime('2025-12-23/23:53:00', '%Y-%m-%d/%H:%M:%S'), c='r')
# ax.axvline( datetime.datetime.strptime('2025-12-24/00:03:00', '%Y-%m-%d/%H:%M:%S'), c='r')
# ax.axvline( datetime.datetime.strptime('2025-12-24/00:13:00', '%Y-%m-%d/%H:%M:%S'), c='r')

# ax.axvline( datetime.datetime.strptime('2025-12-23/23:41:00', '%Y-%m-%d/%H:%M:%S'), c='r')
# ax.axvline( datetime.datetime.strptime('2025-12-23/23:51:00', '%Y-%m-%d/%H:%M:%S'), c='r')
# ax.axvline( datetime.datetime.strptime('2025-12-24/00:01:00', '%Y-%m-%d/%H:%M:%S'), c='r')
# ax.axvline( datetime.datetime.strptime('2025-12-24/00:11:00', '%Y-%m-%d/%H:%M:%S'), c='r')
# ax.axvline( datetime.datetime.strptime('2025-12-24/00:21:00', '%Y-%m-%d/%H:%M:%S'), c='r')
# ax.axvline( datetime.datetime.strptime('2025-12-24/00:31:00', '%Y-%m-%d/%H:%M:%S'), c='r')
# ax.axvline( datetime.datetime.strptime('2025-12-24/00:41:00', '%Y-%m-%d/%H:%M:%S'), c='r')
# Out:
# [Text(20446.36802614634, 1, '0'),
#  Text(20446.36942332227, 1, '40000'),
#  Text(20446.370820498192, 1, '80000'),
#  Text(20446.37221767412, 1, '120000'),
#  Text(20446.373614850047, 1, '160000'),
#  Text(20446.375012025972, 1, '200000'),
#  Text(20446.376409201897, 1, '240000'),
#  Text(20446.377806377826, 1, '280000'),
#  Text(20446.379203553748, 1, '320000'),
#  Text(20446.380600729677, 1, '360000')]

# %%
# Out:
# datetime.datetime(2025, 12, 23, 23, 3)

# %%
np.vstack( [datadict['q0']['data'][i,:,:] for i in sweep0]  ).shape
# Out:
# (200000, 51)

# %%
parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-12-29\\"


f_id = '08468'
f_id = '08469'
f_id = '08470'

parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-12-30\\"
f_id = '08471'
f_id = '08473'
f_id = '08479'
# f_id = '08480'
f_id = '08481'
f_id = '08482'
f_id = '08483'
# f_id = '08484'
import os
paths = [f for f in os.listdir(parent_path) ]
# path = paths[np.argmax(paths)  ]
path = [x for x in paths if f_id in x][0]
datadict = sqil.extract_h5_data(parent_path+ path, get_metadata=True)

sweep0 = datadict['q0']['sweep0']
z = np.vstack( [datadict['q0']['data'][i,:,:] for i in sweep0]  )
y = datadict['q0']['frequencies'][0,:]
x = np.arange(z.shape[0])

def clip_and_inpaint(z, vmin, vmax):
    z = z.copy()
    ny, nx = z.shape
    def neighbors(i, j):
        for di, dj in [(-1,0),(1,0),(0,-1),(0,1)]:
            ni, nj = i + di, j + dj
            if 0 <= ni < ny and 0 <= nj < nx:
                yield ni, nj
    mask = (np.abs(z) < vmin) | (np.abs(z) > vmax)
    for i, j in np.argwhere(mask):
        vals = []
        for ni, nj in neighbors(i, j):
            if vmin <= np.abs(z[ni, nj]) <= vmax:
                vals.append(z[ni, nj])
        if vals:  # assumed to exist
            z[i, j] = np.mean(vals)
    return z

N_avg = 500

z_ds = z[:len(z)//N_avg * N_avg].reshape(-1, N_avg, z.shape[1]).mean(axis=1)
x_ds = x[::N_avg]
# plt.figure(figsize=(15,6))
# plt.pcolormesh( x_ds, y, np.angle(z_ds).T  )
# # plt.pcolormesh( x_ds, y, np.abs(z_ds).T  )
# plt.show()

import matplotlib.dates as mdates
import datetime
start_path = parent_path + path + r'\qpu_old.json'
start_time=datetime.datetime.fromtimestamp(os.path.getmtime(start_path))
end_path = parent_path + path + r'\data.ddh5'
end_time=datetime.datetime.fromtimestamp(os.path.getmtime(end_path))

shot_count = 10000
time_list = np.linspace( start_time, end_time, len(x_ds))
index_list = np.arange( len(x_ds), dtype=int) * N_avg

fig, axs = plt.subplots(1,1,figsize=(15,6))

ax = axs
ax.pcolormesh( time_list, y, np.angle(z_ds).T  )


max_labels = 10
step = max(1, len(index_list) // max_labels)
tick_positions = mdates.date2num(time_list[::step])
tick_labels = index_list[::step]
secax = ax.secondary_xaxis('top')
secax.set_xticks(tick_positions)
secax.set_xticklabels(tick_labels)
plt.title([ x for x in parent_path.split('\\') if len(x)>0 ][-1] + '\\' + f_id)
# Out:
# Text(0.5, 1.0, '2025-12-30\\08483')

# %%
[ x for x in parent_path.split('\\') if len(x)>0 ][-1]
# Out:
# '2025-12-30'

# %% [markdown]
# #### T1 from files

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
path_T1_files = r'Z:\Users\Chien-An Wang\stormcrow'
if path_T1_files not in sys.path:
    sys.path.insert(1, path_T1_files)
# %matplotlib qt

# %%
from analysis_2025_1212_05075_to_05418_T1 import analysis_result as analysis_result0
from analysis_2025_1225_06276_to_06466_T1 import analysis_result as analysis_result1
from analysis_2025_1225_06473_to_06661_T1 import analysis_result as analysis_result2
from analysis_2025_1225_06674_to_1226_07072_T1 import analysis_result as analysis_result3
from analysis_2025_1226_07073_to_1227_07474_T1 import analysis_result as analysis_result4
from analysis_2025_1227_07484_to_07843_T1 import analysis_result as analysis_result5
from analysis_2025_1227_07850_to_1228_08354_T1 import analysis_result as analysis_result6
from analysis_2025_1230_08548_to_1231_09452_T1 import analysis_result as analysis_result7
from analysis_2025_1231_09453_to_0101_10113_T1 import analysis_result as analysis_result8
from analysis_2026_0101_10114_to_0102_10809_T1 import analysis_result as analysis_result9
from analysis_2026_0102_10810_to_0103_11435_T1 import analysis_result as analysis_result10
from analysis_2026_0103_2 import analysis_result as analysis_result11

# %%
# result11 = analysis_result11(return_result=True, plot=True, plot_T1_fitfail=False, plot_freq_fitfail=False, plot_msk_T1=False, plot_transmon_T1_fitfail=False)

# %%
result10 = analysis_result10(return_result=True, plot=True, plot_T1_fitfail=False, plot_freq_fitfail=False, plot_msk_T1=False, plot_transmon_T1_fitfail=False)
result9 = analysis_result9(return_result=True, plot=True, plot_T1_fitfail=True, plot_freq_fitfail=False, plot_msk_T1=True, plot_transmon_T1_fitfail=True)
result8 = analysis_result8(return_result=True, plot=True, plot_T1_fitfail=False, plot_freq_fitfail=False, plot_msk_T1=False, plot_transmon_T1_fitfail=False)
result7 = analysis_result7(return_result=True, plot=False, plot_T1_fitfail=False, plot_freq_fitfail=False, plot_msk_T1=False, plot_transmon_T1_fitfail=False)

result0 = analysis_result0(return_result=True, plot=False, plot_T1_fitfail=False, plot_freq_fitfail=False, plot_msk_T1=False)
result1 = analysis_result1(return_result=True, plot=False, plot_T1_fitfail=False, plot_freq_fitfail=False, plot_msk_T1=False)
result2 = analysis_result2(return_result=True, plot=False, plot_T1_fitfail=False, plot_freq_fitfail=False, plot_msk_T1=False)
result3 = analysis_result3(return_result=True, plot=False, plot_T1_fitfail=False, plot_freq_fitfail=False, plot_msk_T1=False)
result4 = analysis_result4(return_result=True, plot=False, plot_T1_fitfail=False, plot_freq_fitfail=False, plot_msk_T1=False)
result5 = analysis_result5(return_result=True, plot=False, plot_T1_fitfail=False, plot_freq_fitfail=False, plot_msk_T1=False)
result6 = analysis_result6(return_result=True, plot=False, plot_T1_fitfail=False, plot_freq_fitfail=False, plot_msk_T1=False)

# %%
cmap = plt.cm.Blues
fig, ax = plt.subplots(1,1)
# for return_obj in [   result4  ]:
# for return_obj in [  result3, result4]:
# for return_obj in [ result1, result2, result3, result4]:
for i, return_obj in enumerate(  [result0, result1, result2, result3, result4, result5, result6, result7, result8, result9, result10]   ):  
    alpha = 0.2 if  return_obj is  result0 else 1
    ax.errorbar(return_obj['T1_vs_freq']['freqs'], return_obj['T1_vs_freq']['T1s'], 
                # xerr=return_obj['T1_vs_freq']['freqs_err'], 
                #  yerr=return_obj['T1_vs_freq']['T1s_err'],
                fmt="-o", capthick=1, elinewidth=1, label='', alpha=alpha,  linewidth=1, markersize=3) #, c=cmap(0.3 + i/20))
    ax.set_xlabel('frequency (MHz)')  
    ax.set_ylabel('T1 (ms)')  
    ax.grid(visible=True, which='major')
    ax.grid(visible=True, which='minor')
    ax.set_ylim(0.1, 22)    
plt.show()
plt.yscale('log')

# %%
cmap = plt.cm.Blues
fig, ax = plt.subplots(1,1)
# for return_obj in [   result4  ]:
# for return_obj in [  result3, result4]:
# for return_obj in [ result1, result2, result3, result4]:
for i, return_obj in enumerate(  [ result7, result8, result9, result10]   ):  
    ax.errorbar(return_obj['transmon_T1_vs_flux']['freqs'], return_obj['transmon_T1_vs_flux']['T1s'], 
                # xerr=return_obj['T1_vs_freq']['freqs_err'], 
                #  yerr=return_obj['T1_vs_freq']['T1s_err'],
                fmt="-o", capthick=1, elinewidth=1, label='',   linewidth=1, markersize=3, ) # c=cmap(0.3 + i/8))
    ax.set_xlabel('frequency (MHz)')  
    ax.set_ylabel('T1 (ms)')  
    ax.grid(visible=True, which='major')
    ax.grid(visible=True, which='minor')
    ax.set_ylim(0.1, 22)    
plt.show()
plt.yscale('log')

# %%
fig, axs = plt.subplots(2,1)
# for return_obj in [   result3, result4]:
# for return_obj in [ result1, result2, result3, result4]:
for return_obj in [result0, result1, result2, result3, result4, result5, result6]:
    ax = axs[0]
    ax.errorbar(return_obj['T1_vs_flux']['fluxs'], return_obj['T1_vs_flux']['T1s'], yerr=return_obj['T1_vs_flux']['T1s_err'],
                fmt="-o", capthick=2, elinewidth=2, label='')
    ax.set_xlabel('flux (Phi_0)')    
    ax.set_ylabel('T1 (ms)')  
    ax.set_yscale('log')
    # plt.tick_params(axis='y', which='minor')
    ax.grid(visible=True, which='major')
    ax.grid(visible=True, which='minor')
    ax.set_ylim(0.1, 22)
    ax = axs[1]
    ax.errorbar(return_obj['freq_vs_flux']['fluxs'], return_obj['freq_vs_flux']['freqs'], yerr=return_obj['freq_vs_flux']['freqs_err'],
                fmt="-o", capthick=2, elinewidth=2, label='')
    ax.plot(fluxs, 1e3 * np.array([current_to_energy(x, drift_curr= drift_curr_correction)[1] for x in currents])  )
    ax.set_xlabel('flux (Phi_0)')   
    ax.set_ylabel('frequency (MHz)')  
    
plt.show()

# %%
###
fig, ax = plt.subplots(1,1)
# for return_obj in [   result4  ]:
# for return_obj in [  result3, result5, result6]:
# for return_obj in [ result1, result2, result3, result5, result6 ]:
# for return_obj in [result0, result1, result2, result3, result4, result5, result6]:
for i, return_obj in enumerate([result0, result1, result2, result3, result4, result5, result6, result7, result8, result9, result10]):
    # if i in [0, 1, 2, 4]:
    #     continue
    alpha = 0.2 if  return_obj is  result0 else 1
    ax.errorbar(return_obj['T1_vs_freq']['freqs'], 1/return_obj['T1_vs_freq']['T1s'], 
                # xerr=return_obj['T1_vs_freq']['freqs_err'], 
                # yerr=return_obj['T1_vs_freq']['T1s_err']/(return_obj['T1_vs_freq']['T1s']**2),
                fmt="-o", capthick=1, elinewidth=1, label='', alpha=alpha, linewidth=1, markersize=3, color=f'C{i}')
    ax.set_xlabel('frequency (MHz)')  
    ax.set_ylabel( r'$\Gamma$'+ ' (1/ms)')  
    ax.grid(visible=True, which='major')
    ax.grid(visible=True, which='minor')
    # ax.set_ylim(0.1, 22)    
plt.show()
plt.yscale('log')
# plt.xscale('log')

# %%
###
fig, ax = plt.subplots(1,1)
# for return_obj in [   result4  ]:
# for return_obj in [  result3, result4]:
# for return_obj in [ result1, result2, result3, result5, result6 ]:
for return_obj in [result0, result1, result2, result3, result4, result5, result6]:
    alpha = 0.2 if  return_obj is  result0 else 1
    ax.errorbar(return_obj['T1_vs_freq']['freqs'], 1/return_obj['T1_vs_freq']['T1s'], xerr=return_obj['T1_vs_freq']['freqs_err'], 
                fmt="-o", capthick=1, elinewidth=1, label='', alpha=alpha, linewidth=1, markersize=3)
    ax.set_xlabel('frequency (MHz)')  
    ax.set_ylabel( r'$\Gamma$'+ ' (ms^-1)')  
    ax.grid(visible=True, which='major')
    ax.grid(visible=True, which='minor')
    # ax.set_ylim(0.1, 22)    
plt.show()
plt.yscale('log')

# %%
fig, axs = plt.subplots(1,1)

# for return_obj in [ result1, result2, result3]:
for return_obj in [result0, result1, result2, result3, result4, result5, result6]:
    alpha = 0.2 if  return_obj is  result0 else 1
    ax = axs
    ax.errorbar(return_obj['T1_vs_flux']['fluxs'], return_obj['T1_vs_flux']['T1s'], yerr=return_obj['T1_vs_flux']['T1s_err'],
                fmt="-o", capthick=2, elinewidth=2, label='', alpha=alpha)
    ax.set_xlabel('flux (Phi_0)')    
    ax.set_ylabel('T1 (ms)')  
    ax.set_yscale('log')
    # plt.tick_params(axis='y', which='minor')
    ax.grid(visible=True, which='major')
    ax.grid(visible=True, which='minor')
    ax.set_ylim(0.1, 22)

    
plt.show()

# %%
current_to_energy(0.8286e-3, drift_curr= -0.73e-6)
# Out:
# array([0.        , 0.36625898, 5.35316026, 5.71042259])

# %%
paths_select[id_transmon[i]]
# Out:
# 'C:\\Users\\sqil\\Desktop\\data_local\\20251110_stormcrow_N17\\2025-12-30\\\\08548-qubit_spectroscopy_2025-12-30T170252'

# %%
plt.figure()
plt.gca().errorbar( [0,1,2], [0,1,2])
plt.grid(False)
plt.show()

# %%
from sqil_experiments.measurements.T1 import analyze_T1
from sqil_experiments.measurements.qu_spec import qu_spec_analysis
import matplotlib.pyplot as plt

path = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-12\05405-qubit_spectroscopy_hdawg_2025-12-12T082044"

res = qu_spec_analysis(path=path)
plt.close('all')
# res.updated_params
# res.fits # T1 is parameter 1

# %%
import sqil_core as sqil
qpu = sqil.read_qpu(path, "qpu_old.json").quantum_elements[0].parameters.current
qpu.quantum_elements[0].parameters.current
# Out:
# 0.0008284

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib qt
import os
import sqil_core as sqil
from sqil_experiments.measurements.T1 import analyze_T1
from sqil_experiments.measurements.qu_spec import qu_spec_analysis

parent_path = r"C:\Users\sqil\Desktop\data_local\20251110_stormcrow_N17\2025-12-12\\"

paths = [f for f in os.listdir(parent_path) ]
start_id, end_id = '05075', '05418'

start, end = [i for i in range(len(paths)) if start_id in paths[i] or end_id in paths[i]]
paths_select = paths[start:end+1]

id_T1 = [i for i in range(len(paths_select)) if 'T1_hdawg' in paths_select[i] ]
id_freq_ = [i for i in range(len(paths_select)) if 'qubit_spectroscopy_hdawg' in paths_select[i] ]

id_freq = np.zeros_like(id_T1, dtype=int)
for i in range(len(id_T1)):
    id_freq[i] = id_freq_[np.where( np.array(id_freq_) < id_T1[i] )[0][-1]  ]

currents = np.zeros((len(id_T1),))
T1s = np.zeros((len(id_T1),))
T1s_err = np.zeros((len(id_T1),))
freqs = np.zeros((len(id_T1),))
freqs_err = np.zeros((len(id_T1),))
map_currents_idT1 = np.zeros((len(id_T1),2), dtype=object)
T1_paths =  list(np.zeros((len(id_T1),)))
freq_paths = list(np.zeros((len(id_T1),)))
for i in range(len(id_T1)):
    
    currents[i] = sqil.read_qpu(parent_path+paths_select[id_T1[i]], "qpu_old.json").quantum_elements[0].parameters.current
    res = analyze_T1(path=parent_path+paths_select[id_T1[i]])
    plt.close('all')
    if res.fits != {}: 
        A, T1s[i], y0 = res.fits['q0 - fit'].params  # [A, tau, y0]
        A_err, T1s_err[i], y0_err = res.fits['q0 - fit'].std_err

    res = qu_spec_analysis(path=parent_path+paths_select[id_freq[i]])
    plt.close('all')   
    if res.fits != {}: 
        if len(res.fits['q0 - Combined mag-phase fit'].params) == 4:
            _, _, freqs[i], _ = res.fits['q0 - Combined mag-phase fit'].params  # [? ? ? ?]
            _, _, freqs_err[i], _ = res.fits['q0 - Combined mag-phase fit'].std_err  # [? ? ? ?]
        else:
            freqs[i] = res.fits['q0 - Combined mag-phase fit'].params[6]  # [?,]*7
            freqs_err[i] = res.fits['q0 - Combined mag-phase fit'].std_err[6]  # [?,]*7
    map_currents_idT1[i,:] = currents[i], paths_select[id_T1[i]]
    T1_paths[i] = parent_path+paths_select[id_T1[i]]
    freq_paths[i] = parent_path+paths_select[id_freq[i]]


# res = analyze_T1(path=path)
# Out:
# Gaussian dominates
#  -> nrmse: 0.0356 vs 0.0347
# Gaussian dominates
#  -> nrmse: 0.0336 vs 0.0220
# c:\Users\sqil\AppData\Local\pypoetry\Cache\virtualenvs\sqil-experiments-gl8RHkKX-py3.12\Lib\site-packages\sqil_core\fit\_fit.py:366: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(

# %%
def current_to_energy(current_val=0.9e-3, half_flux=0.847e-3, drift_curr = -0.6e-6, ):
    import pickle
    with open(r"C:\Users\sqil\Desktop\New_folder\fit_data_finer.pkl", "rb") as f:
        x_fit_loaded, y_fit_loaded = pickle.load(f)
    def current_to_flux(curr, zero_flux_curr, half_flux_curr):
        span = half_flux_curr - zero_flux_curr
        return (curr - zero_flux_curr) / span / 2
    def flux_to_current(flux, zero_flux_curr, half_flux_curr):
        span = half_flux_curr - zero_flux_curr
        return flux * 2 * span + zero_flux_curr
    curr_half_flux = half_flux + drift_curr  # 0.9025e-3  + drift_curr
    curr_flux_period = 0.71295e-3
    curr_zero_flux = curr_half_flux - curr_flux_period
    x_fit_curr =  flux_to_current(x_fit_loaded, curr_zero_flux, curr_half_flux)

    closest_id = np.argmin(abs(x_fit_curr - current_val))
    x_to_interp = x_fit_curr[closest_id-1:closest_id+2]
    energies = [0,]
    for i in range(3):
        y_to_interp = y_fit_loaded[closest_id-1:closest_id+2,i]
        energies += [np.interp(current_val, x_to_interp, y_to_interp),]
    return np.array(energies)
drift_currs = np.linspace(-1e-6, -0.5e-6, 101)
msk = (freqs > 85e6)  & (freqs > freqs_err  )

costs = []
for drift_curr in drift_currs:
    delta = freqs[msk]*1e-6 - 1e3*np.array([current_to_energy(x, drift_curr= drift_curr)[1] for x in currents[msk] ])
    costs += [np.sqrt(np.sum(delta**2))]
costs = np.array(costs)    
cost_min_id = np.argmin(costs)
coeffs = np.polyfit(drift_currs[cost_min_id-1:cost_min_id+2], costs[cost_min_id-1:cost_min_id+2] ,2 )
drift_curr_correction = -0.5*coeffs[1]/coeffs[0]

# %%
fluxs = 0.5 + (currents - (0.847e-3 + drift_curr_correction)  )/(2*0.71295e-3)

fig, axs = plt.subplots(2,1)

ax = axs[0]
msk_T1 = (T1s > 0) & (T1s<1) & (T1s > T1s_err  ) & (np.array([False if i in [3, 30, 48] else True for i in range(len(T1s))]))
# msk_T1 = (T1s > 0) & (T1s<1) & (T1s > T1s_err  )
msk = msk_T1.copy()
ax.errorbar(fluxs[msk], T1s[msk]*1e3, yerr=T1s_err[msk]*1e3,
            fmt="-o", capthick=2, elinewidth=2, label='')
ax.set_xlabel('flux (Phi_0)')    
ax.set_ylabel('T1 (ms)')          
ax = axs[1]
msk_freq = (freqs > 85e6)  & (freqs > freqs_err  )
msk = msk_freq.copy()
ax.errorbar(fluxs[msk], freqs[msk]/1e6, yerr=freqs_err[msk]/1e6,
            fmt="-o", capthick=2, elinewidth=2, label='')
ax.plot(fluxs, 1e3 * np.array([current_to_energy(x, drift_curr= drift_curr_correction)[1] for x in currents])  )
ax.set_xlabel('flux (Phi_0)')   
ax.set_ylabel('frequency (MHz)')  
plt.show()

# %%
fig, ax = plt.subplots(1,1)

msk = msk_T1.copy() 
freqs_processed = np.zeros_like(T1s)
for i in range(len(T1s)):
    if  (freqs[i]  > 85e6)  and (freqs[i]  > freqs_err[i]  ):
        freqs_processed[i] = 1e9*current_to_energy(currents[i], drift_curr= drift_curr_correction)[1] #freqs[i] 
    else:
        freqs_processed[i] = 1e9*current_to_energy(currents[i], drift_curr= drift_curr_correction)[1]

ax.errorbar(freqs_processed[msk]/1e6, T1s[msk]*1e3, xerr=freqs_err[msk]/1e6, yerr=T1s_err[msk]*1e3,
            fmt="-o", capthick=2, elinewidth=2, label='')
ax.set_xlabel('frequency (MHz)')  
ax.set_ylabel('T1 (ms)')  
plt.show()
plt.yscale('log')

# %%
print_str = []
# for search_current in [0.8348e-3, 0.8276e-3, 0.83e-3 ] :
# for search_current in [0.8244e-3 ] :   
for search_current in [0.846e-3 ] :  
    search_id = np.argmin(abs(map_currents_idT1[:,0] - search_current))
    print_str += [map_currents_idT1[search_id,1],]
print_str
# Out:
# ['05109-T1_hdawg_2025-12-12T003844']

# %%
# for i in range(len(T1s)):
# for i in range(30, 55):   
# for i in range(0, 20): 
# for i in range(20, 40):     #  range(0, 17):  
for i in range(40, 55):
# for i in [3, 30, 48]:

    if  msk_T1[i] and i not in [3, 30, 48]:
        res = analyze_T1(path=T1_paths[i])
        plt.show()
        # plt.close('all')  
        A, T1s[i], y0 = res.fits['q0 - fit'].params  # [A, tau, y0]
        xdata, ydata = sqil.utils.extract_h5_data(T1_paths[i], ["q0/time", "q0/data"])
        print(i, currents[i])
        # print(T1s[i], currents[i], A, abs(ydata[-1]) - abs(ydata[0]))
# Out:
# 40 0.0008308
# 41 0.0008304
# 42 0.00083
# 43 0.0008296
# 44 0.0008292
# 45 0.0008288
# 46 0.0008284
# 47 0.000828
# 49 0.0008271999999999999
# 51 0.0008252
# 52 0.0008248
# 53 0.0008244

# %%
for i in range(len(T1s)):
    if currents[i]

# %%
direction:
0.000846

fit:
0.8348e-3
0.8276
# Out:
# 55

# %%
# for i in [30]:
# for i in range(0, 20):    

# for i in range(20, 40): 
for i in range(40, 55): 
    if  msk_T1[i]:
        plt.figure()

        x, y = sqil.utils.extract_h5_data(T1_paths[i], ["q0/time", "q0/data"])
        # plt.plot(xdata, abs(ydata))
        plt.plot( y.imag )
        # plt.plot( abs(y) )

        x_f, y_f = sqil.utils.extract_h5_data(freq_paths[i], ["q0/frequencies", "q0/data"])
        # plt.plot(xdata, abs(ydata))
        plt.plot( y_f.imag )
        # plt.plot( abs(y_f) )

        plt.show()

# %%
datadict['q0']['data_g'].shape, datadict['q0']['sweep0']
# Out:
# ((19, 101),
#  array([5.3500e+09, 5.3505e+09, 5.3510e+09, 5.3515e+09, 5.3520e+09,
#         5.3525e+09, 5.3530e+09, 5.3535e+09, 5.3540e+09, 5.3545e+09,
#         5.3550e+09, 5.3555e+09, 5.3560e+09, 5.3565e+09, 5.3570e+09,
#         5.3575e+09, 5.3580e+09, 5.3585e+09, 5.3590e+09]))

# %% [markdown]
# #### IQ plane

# %%
from sqil_core.utils import * 
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,1, figsize=(5,5))

path_blobs = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-02\01120-single_shot_hdawg_2025-12-02T125717"
g,e = extract_h5_data(path_blobs, ["q0/g", "q0/e"])
ax.scatter(np.mean(g.real), np.mean(g.imag), marker="v", color="cyan", label=r"$|g\rangle$", zorder=100)
ax.scatter(np.mean(e.real), np.mean(e.imag), marker="^", color="red", label=r"$|e\rangle$", zorder=100)

path_rabi = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-02\01113-time_rabi_2025-12-02T123213"
data_rabi = extract_h5_data(path_rabi, ["q0/data"])
ax.plot(data_rabi.real, data_rabi.imag, 'o', label="Rabi")

path_T1 = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-02\01152-T1_hdawg_2025-12-02T141155"
data_T1 = extract_h5_data(path_T1, ["q0/data"])
ax.plot(data_T1.real, data_T1.imag, 'o', label="T1")

path_T1 = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-02\01154-T1_hdawg_2025-12-02T141558"
data_T1 = extract_h5_data(path_T1, ["q0/data"])
ax.plot(data_T1.real, data_T1.imag, 'o', label="T1_g")

path_T2 = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-02\01163-T2_echo_hdawg_2025-12-02T143504"
data_T2 = extract_h5_data(path_T2, ["q0/data"])
ax.plot(data_T2.real, data_T2.imag, 'o', label="T2")

ax.axis('equal')
ax.grid(True)
ax.legend()
plt.show()

# %%
10e-9 / 500e-6
# Out:
# 2e-05

# %%
path = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-02\01129-single_shot_hdawg_vs_aux_drive_length_2025-12-02T133144"

gs, es = extract_h5_data(path, ["q0/g", 'q0/e'])

for i in range(len(gs)):
    p = plt.plot(np.mean(gs[i].real), np.mean(gs[i].imag), 'o', label=f"g {i}")
    color = p[0].get_color()
    plt.plot(np.mean(es[i].real), np.mean(es[i].imag), 'x', color=color)

plt.legend()

plt.show()

# %%
len(gs)
colors = ["red", "blue", "red", ""]
# Out:
# 11

# %%
from sqil_core.utils import * 
import numpy as np
import matplotlib.pyplot as plt

path = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2025-12-08\04242-time_rabi_vs_aux_reset_delay_length_2025-12-08T164751"

delay, data = extract_h5_data(path, ["q0/sweep0", "q0/data"])

plt.figure()
for i in range(len(delay)):
    if i % 2 == 0:
        continue
    plt.plot(data[i,:].real, data[i,:].imag, 'o', label=f"{delay[i]*1e6:.3f} us")

plt.legend()
plt.show()

# %%
data.shape
# Out:
# (21, 81)

# %% [markdown]
# Spectroscopy IQ plane

# %%
# %matplotlib inline

fig, ax = plt.subplots(1,1, figsize=(5,5))

# path_g_ge = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2026-01-06\11723-qubit_spectroscopy_2026-01-06T190401"
# d = extract_h5_data(path_g_ge, ["q0/data"])
# ax.scatter(d.real, d.imag, label=r"Spec g $\rightarrow$ ge")

path_g_ef = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2026-01-06\11725-time_rabi_2026-01-06T190713"
d = extract_h5_data(path_g_ef, ["q0/data"])
ax.scatter(d.real, d.imag, label=r"Rabi g $\rightarrow$ ge")

path_e_ge = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2026-01-06\11733-qubit_spectroscopy_2026-01-06T193250"
d = extract_h5_data(path_e_ge, ["q0/data"])
ax.scatter(d.real, d.imag, label=r"Spec e $\rightarrow$ ef")

path_rabi_ef = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2026-01-06\11725-time_rabi_2026-01-06T190713"
d = extract_h5_data(path_rabi_ef, ["q0/data"])
ax.scatter(d.real, d.imag, label=r"Rabi e $\rightarrow$ ef")

path_g_ef = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2026-01-06\11724-qubit_spectroscopy_aux_2026-01-06T190510"
d = extract_h5_data(path_g_ef, ["q0/data"])
ax.scatter(d.real, d.imag, label=r"Aux spec e $\rightarrow$ ef")


path_rabi_ef= r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2026-01-06\11722-time_rabi_aux_2026-01-06T185146"
d = extract_h5_data(path_rabi_ef, ["q0/data"])
ax.scatter(d.real, d.imag, label=r"Aux Rabi e $\rightarrow$ ef")

path_blobs = r"Z:\Projects\Stormcrow\data\20251110_stormcrow_N17\2026-01-06\11739-single_shot_2026-01-06T194329"
g,e = extract_h5_data(path_blobs, ["q0/g", "q0/e"])
ax.scatter(np.mean(g.real), np.mean(g.imag), marker="v", color="cyan", label=r"$|g\rangle$", zorder=100)
ax.scatter(np.mean(e.real), np.mean(e.imag), marker="^", color="magenta", label=r"$|e\rangle$", zorder=100)


ax.axis('equal')
ax.grid(True)
ax.legend()
plt.show()
